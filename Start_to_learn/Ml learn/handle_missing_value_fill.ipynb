# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("Bank_data.csv")

# %%
dataset.head(10)
# Out:
#   loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0  LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1  LN1001     Yes    Male          0           Yes        NaN       2995.0
# 2  LN1002     Yes    Male          1            No    21923.0       3046.0
# 3  LN1003     NaN  Female         3+            No    19718.0      14947.0
# 4  LN1004     Yes  Female         3+           Yes     9636.0        319.0
# 5  LN1005     Yes    Male          1           Yes     9129.0       4606.0
# 6  LN1006      No     NaN          1           Yes    19098.0       2451.0
# 7  LN1007      No  Female          1           Yes    13431.0      11621.0
# 8  LN1008      No  Female          0            No     2105.0       8731.0
# 9  LN1009     Yes  Female          0            No    10321.0       9293.0
#
#    Loan_amount  creadit_his    propert loan_status
# 0     133487.0          0.0      Rural    Rejected
# ...

# %%
dataset.isnull().sum()
# Out:
# loan_id           0
# married          23
# gender           32
# dependency       17
# Self_Employee    25
# Applicant        38
# coapplicant      27
# Loan_amount      32
# creadit_his      26
# propert          27
# loan_status      25
# dtype: int64

# %%
# dataset.fillna(10).head(10)  #fill the missing value in your dataset with input

# %%
dataset.fillna(method="ffill") # colum paste nan value use forword filling
# Out:
# C:\Users\lenovo\anaconda3\ipykernel_7052\522716564.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill") # colum paste nan value use forword filling
#     loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0    LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1    LN1001     Yes    Male          0           Yes    17154.0       2995.0
# 2    LN1002     Yes    Male          1            No    21923.0       3046.0
# 3    LN1003     Yes  Female         3+            No    19718.0      14947.0
# 4    LN1004     Yes  Female         3+           Yes     9636.0        319.0
# ..      ...     ...     ...        ...           ...        ...          ...
# 613  LN1613      No  Female          2           Yes     4372.0      11822.0
# 614  LN1614      No  Female          2           Yes     3614.0       6723.0
# ...

# %%
dataset.fillna(method="bfill") #Row cell paste in nan value use backword filling  #axios=1
# Out:
# C:\Users\lenovo\anaconda3\ipykernel_7052\3490481378.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill") #Row cell paste in nan value use backword filling  #axios=1
#     loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0    LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1    LN1001     Yes    Male          0           Yes    21923.0       2995.0
# 2    LN1002     Yes    Male          1            No    21923.0       3046.0
# 3    LN1003     Yes  Female         3+            No    19718.0      14947.0
# 4    LN1004     Yes  Female         3+           Yes     9636.0        319.0
# ..      ...     ...     ...        ...           ...        ...          ...
# 613  LN1613      No  Female          2           Yes     4372.0      11822.0
# ...

# %%
dataset["gender"].mode()[0]  #create a mode function to find the most common gender
dataset.fillna(dataset["gender"].mode(0)[0]).head(7)
# Out:
#   loan_id married  gender dependency Self_Employee Applicant coapplicant  \
# 0  LN1000     Yes  Female          0           Yes   17154.0     13688.0
# 1  LN1001     Yes    Male          0           Yes    Female      2995.0
# 2  LN1002     Yes    Male          1            No   21923.0      3046.0
# 3  LN1003  Female  Female         3+            No   19718.0     14947.0
# 4  LN1004     Yes  Female         3+           Yes    9636.0       319.0
# 5  LN1005     Yes    Male          1           Yes    9129.0      4606.0
# 6  LN1006      No  Female          1           Yes   19098.0      2451.0
#
#   Loan_amount creadit_his    propert loan_status
# 0    133487.0         0.0      Rural    Rejected
# 1     50849.0         1.0      Urban    Rejected
# 2     85520.0         0.0  Semiurban    Rejected
# 3      Female         1.0      Rural    Rejected
# 4    299794.0         0.0      Rural    Rejected
# 5    299643.0         1.0     Female    Approved
# ...

# %%
dataset.head(7)
# Out:
#   loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0  LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1  LN1001     Yes    Male          0           Yes        NaN       2995.0
# 2  LN1002     Yes    Male          1            No    21923.0       3046.0
# 3  LN1003     NaN  Female         3+            No    19718.0      14947.0
# 4  LN1004     Yes  Female         3+           Yes     9636.0        319.0
# 5  LN1005     Yes    Male          1           Yes     9129.0       4606.0
# 6  LN1006      No     NaN          1           Yes    19098.0       2451.0
#
#    Loan_amount  creadit_his    propert loan_status
# 0     133487.0          0.0      Rural    Rejected
# 1      50849.0          1.0      Urban    Rejected
# 2      85520.0          0.0  Semiurban    Rejected
# 3          NaN          1.0      Rural    Rejected
# 4     299794.0          0.0      Rural    Rejected
# 5     299643.0          1.0        NaN    Approved
# ...

# %%
dataset["gender"].mode()[0]  #create a mode function to find the most common gender
dataset.fillna(dataset["gender"].mode()[0], inplace=True)
# Out:
# C:\Users\lenovo\anaconda3\ipykernel_7052\3877062817.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Female' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dataset.fillna(dataset["gender"].mode()[0], inplace=True)

# %%
dataset.head(20)
# Out:
#    loan_id married  gender dependency Self_Employee Applicant coapplicant  \
# 0   LN1000     Yes  Female          0           Yes   17154.0     13688.0
# 1   LN1001     Yes    Male          0           Yes    Female      2995.0
# 2   LN1002     Yes    Male          1            No   21923.0      3046.0
# 3   LN1003  Female  Female         3+            No   19718.0     14947.0
# 4   LN1004     Yes  Female         3+           Yes    9636.0       319.0
# 5   LN1005     Yes    Male          1           Yes    9129.0      4606.0
# 6   LN1006      No  Female          1           Yes   19098.0      2451.0
# 7   LN1007      No  Female          1           Yes   13431.0     11621.0
# 8   LN1008      No  Female          0            No    2105.0      8731.0
# 9   LN1009     Yes  Female          0            No   10321.0      9293.0
# 10  LN1010     Yes    Male         3+            No    Female      8907.0
# 11  LN1011  Female  Female          1           Yes   22330.0      8953.0
# ...
