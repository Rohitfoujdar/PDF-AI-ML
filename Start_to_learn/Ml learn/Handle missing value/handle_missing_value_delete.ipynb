# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("Bank_data.csv")

# %%
dataset.head(4)
# Out:
#   loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0  LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1  LN1001     Yes    Male          0           Yes        NaN       2995.0
# 2  LN1002     Yes    Male          1            No    21923.0       3046.0
# 3  LN1003     NaN  Female         3+            No    19718.0      14947.0
#
#    Loan_amount  creadit_his    propert loan_status
# 0     133487.0          0.0      Rural    Rejected
# 1      50849.0          1.0      Urban    Rejected
# 2      85520.0          0.0  Semiurban    Rejected
# 3          NaN          1.0      Rural    Rejected

# %%
dataset.shapeprint(dataset.shape)
# Out:
# (618, 11)

# %%
dataset.isnull().sum()
# Out:
# loan_id           0
# married          23
# gender           32
# dependency       17
# Self_Employee    25
# coapplicant      27
# Loan_amount      32
# creadit_his      26
# propert          27
# loan_status      25
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(272)

# %%
sns.heatmap(dataset.isnull())
# plt.show()
# Out:
# <Axes: >

# %%
dataset.drop(columns="Applicant") #Delete the Applicant colum in your dataset but not deleting your original csv file
# Out:
#     loan_id married  gender dependency Self_Employee  coapplicant  \
# 0    LN1000     Yes  Female          0           Yes      13688.0
# 1    LN1001     Yes    Male          0           Yes       2995.0
# 2    LN1002     Yes    Male          1            No       3046.0
# 3    LN1003     NaN  Female         3+            No      14947.0
# 4    LN1004     Yes  Female         3+           Yes        319.0
# ..      ...     ...     ...        ...           ...          ...
# 613  LN1613      No  Female          2           Yes      11822.0
# 614  LN1614      No  Female          2           Yes       6723.0
# 615  LN1615     Yes    Male          1           Yes      12379.0
# 616  LN1616      No  Female          1            No       3499.0
# 617  LN1617      No  Female          2            No      10428.0
#
#      Loan_amount  creadit_his    propert loan_status
# 0       133487.0          0.0      Rural    Rejected
# 1        50849.0          1.0      Urban    Rejected
# ...

# %%
dataset.drop(columns="Applicant", inplace=True) # Remove the Applicant column from your original dataset

# %%
dataset.shape
# Out:
# (618, 10)

# %%
dataset.dropna(inplace=True) #This function in your data set delete the none value row

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.isnull()
# Out:
#      loan_id  married  gender  dependency  Self_Employee  coapplicant  \
# 0      False    False   False       False          False        False
# 1      False    False   False       False          False        False
# 2      False    False   False       False          False        False
# 4      False    False   False       False          False        False
# 7      False    False   False       False          False        False
# ..       ...      ...     ...         ...            ...          ...
# 613    False    False   False       False          False        False
# 614    False    False   False       False          False        False
# 615    False    False   False       False          False        False
# 616    False    False   False       False          False        False
# 617    False    False   False       False          False        False
#
#      Loan_amount  creadit_his  propert  loan_status
# 0          False        False    False        False
# ...

# %%
dataset.head()
# Out:
#   loan_id married  gender dependency Self_Employee  coapplicant  Loan_amount  \
# 0  LN1000     Yes  Female          0           Yes      13688.0     133487.0
# 1  LN1001     Yes    Male          0           Yes       2995.0      50849.0
# 2  LN1002     Yes    Male          1            No       3046.0      85520.0
# 4  LN1004     Yes  Female         3+           Yes        319.0     299794.0
# 7  LN1007      No  Female          1           Yes      11621.0     232705.0
#
#    creadit_his    propert loan_status
# 0          0.0      Rural    Rejected
# 1          1.0      Urban    Rejected
# 2          0.0  Semiurban    Rejected
# 4          0.0      Rural    Rejected
# 7          0.0  Semiurban    Approved

# %%
dataset.shape
# Out:
# (417, 10)

# %%
((618-417)/618)*100
# Out:
# 32.5242718446602
