# %%
import pandas as pd

# %%
dataset = pd.DataFrame({"Size":["s","m","l","xl","s","m","l","s","s","l","xl","m"]})
dataset.head(3)
# Out:
#   Size
# 0    s
# 1    m
# 2    l

# %%
ord_data = [["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=ord_data)
oe.fit(dataset[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
dataset["size_en"]=oe.transform(dataset[["Size"]])

# %%
dataset
# Out:
#    Size  size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     l      2.0
# 7     s      0.0
# 8     s      0.0
# 9     l      2.0
# 10   xl      3.0
# 11    m      1.0

# %%
ord_data1 ={"s":9 , "m":8 , "l":7 , "xl":6} #create a dictionary

# %%
dataset["size_en_map3"] = dataset["Size"].map(ord_data1) #Use the map function to map the size to the corresponding ordinal value

# %%
dataset
# Out:
#    Size  size_en  size_en_map  size_en_map2  size_en_map3
# 0     s      0.0            0             0             9
# 1     m      1.0            1             1             8
# 2     l      2.0            2             2             7
# 3    xl      3.0            3             3             6
# 4     s      0.0            0             0             9
# 5     m      1.0            1             1             8
# 6     l      2.0            2             2             7
# 7     s      0.0            0             0             9
# 8     s      0.0            0             0             9
# 9     l      2.0            2             2             7
# 10   xl      3.0            3             3             6
# 11    m      1.0            1             1             8

# %%
data = pd.read_csv("Bank_data.csv")

# %%
data.head()
# Out:
#   loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0  LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1  LN1001     Yes    Male          0           Yes        NaN       2995.0
# 2  LN1002     Yes    Male          1            No    21923.0       3046.0
# 3  LN1003     NaN  Female         3+            No    19718.0      14947.0
# 4  LN1004     Yes  Female         3+           Yes     9636.0        319.0
#
#    Loan_amount  creadit_his    propert loan_status
# 0     133487.0          0.0      Rural    Rejected
# 1      50849.0          1.0      Urban    Rejected
# 2      85520.0          0.0  Semiurban    Rejected
# 3          NaN          1.0      Rural    Rejected
# 4     299794.0          0.0      Rural    Rejected

# %%
data["propert"].fillna(data["propert"].mode()[0],inplace=True)
# Out:
# C:\Users\lenovo\anaconda3\ipykernel_10236\2706319778.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["propert"].fillna(data["propert"].mode()[0],inplace=True)

# %%
data
# Out:
#     loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0    LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1    LN1001     Yes    Male          0           Yes        NaN       2995.0
# 2    LN1002     Yes    Male          1            No    21923.0       3046.0
# 3    LN1003     NaN  Female         3+            No    19718.0      14947.0
# 4    LN1004     Yes  Female         3+           Yes     9636.0        319.0
# ..      ...     ...     ...        ...           ...        ...          ...
# 613  LN1613      No  Female          2           Yes     4372.0      11822.0
# 614  LN1614      No  Female          2           Yes     3614.0       6723.0
# 615  LN1615     Yes    Male          1           Yes    14451.0      12379.0
# 616  LN1616      No  Female          1            No    15067.0       3499.0
# 617  LN1617      No  Female          2            No     7912.0      10428.0
#
# ...

# %%
en_ord_data = [["Rural" , "Urban" , "Semiurban"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oen = OrdinalEncoder(categories=en_ord_data)
data["propert"] = oen.fit_transform(data[["propert"]])

# %%
data
# Out:
#     loan_id married  gender dependency Self_Employee  Applicant  coapplicant  \
# 0    LN1000     Yes  Female          0           Yes    17154.0      13688.0
# 1    LN1001     Yes    Male          0           Yes        NaN       2995.0
# 2    LN1002     Yes    Male          1            No    21923.0       3046.0
# 3    LN1003     NaN  Female         3+            No    19718.0      14947.0
# 4    LN1004     Yes  Female         3+           Yes     9636.0        319.0
# ..      ...     ...     ...        ...           ...        ...          ...
# 613  LN1613      No  Female          2           Yes     4372.0      11822.0
# 614  LN1614      No  Female          2           Yes     3614.0       6723.0
# 615  LN1615     Yes    Male          1           Yes    14451.0      12379.0
# 616  LN1616      No  Female          1            No    15067.0       3499.0
# 617  LN1617      No  Female          2            No     7912.0      10428.0
#
# ...
