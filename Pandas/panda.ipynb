# %% [markdown]
# Introduction of pandas
#
# What is pandas?
# A powerfull library of data manipiulation and anaylsis in python. Provides data structure Series and data frame.

# %%
print("Introduction of pandas")
# Out:
# Introduction of pandas

# %%
# !pip install pandas
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 get_ipython().system('pip install pandas')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\utils\_process_win32.py:138, in system(cmd)
#     136 if path is not None:
#     137     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 138 res = process_handler(cmd, _system_body)
#     139 assert isinstance(res, int | type(None))
#     140 return res
#
# ...

# %%
# !python -m pip install --upgrade pip
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().system('python -m pip install --upgrade pip')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\utils\_process_win32.py:138, in system(cmd)
#     136 if path is not None:
#     137     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 138 res = process_handler(cmd, _system_body)
#     139 assert isinstance(res, int | type(None))
#     140 return res
#
# ...

# %%
# !pip --version
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().system('pip --version')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\utils\_process_win32.py:138, in system(cmd)
#     136 if path is not None:
#     137     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 138 res = process_handler(cmd, _system_body)
#     139 assert isinstance(res, int | type(None))
#     140 return res
#
# ...

# %%
# !pip install pandas
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().system('pip install pandas')
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\zmqshell.py:655, in ZMQInteractiveShell.system_piped(self, cmd)
#     653         if path is not None:
#     654             cmd = f"pushd {path} &&{cmd}"
# --> 655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
#     657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\utils\_process_win32.py:138, in system(cmd)
#     136 if path is not None:
#     137     cmd = '"pushd %s &&"%s' % (path, cmd)
# --> 138 res = process_handler(cmd, _system_body)
#     139 assert isinstance(res, int | type(None))
#     140 return res
#
# ...

# %% [markdown]
# #Key data structure in python
#
# 1.Series (1D)
# 2.Dataframe (2D)

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4, 5, 6], index = ['a', 'b', 'c', 'd', 'e', 'f'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
df = pd.DataFrame({"Name":["Rohit", "Mayank", "Foujdar"], "Marks":[100, 55, 88]})

# %%
df
# Out:
#       Name  Marks
# 0    Rohit    100
# 1   Mayank     55
# 2  Foujdar     88

# %% [markdown]
# #CSV or EXECL file read using pandas

# %%
df = pd.read_csv("employee_data.csv", encoding="ISO-8859-1")

# %%
df
# Out:
#       Name  Age  Working Years  Salary   Location
# 0     Amit   56              9  145902     Mumbai
# 1    Rohit   49             12  194793     Mumbai
# 2   Suresh   37              3  160499     Jaipur
# 3   Mahesh   37             15  148495  Bangalore
# 4    Pooja   56             12  164367  Hyderabad
# 5     Neha   58             27  102052    Kolkata
# 6   Vikram   52             19   41908  Bangalore
# 7    Kiran   49             18   77144  Ahmedabad
# 8   Rajesh   22             31   82206  Ahmedabad
# 9   Anjali   27             28  194642    Lucknow
# 10   Sneha   55             14   85237    Kolkata
# 11   Arjun   30              1   31116     Mumbai
# 12  Deepak   28             22   75739  Hyderabad
# 13  Kavita   57             33  147395       Pune
# 14   Suman   47             35  153015      Delhi
# 15   Nitin   41             25   28469      Delhi
# 16   Priya   58             19   43709  Bangalore
# 17  Ramesh   36              4  191159    Kolkata
# ...

# %%
df.head()  #Using 5 data row show in starting
# Out:
#      Name  Age  Working Years  Salary   Location
# 0    Amit   56              9  145902     Mumbai
# 1   Rohit   49             12  194793     Mumbai
# 2  Suresh   37              3  160499     Jaipur
# 3  Mahesh   37             15  148495  Bangalore
# 4   Pooja   56             12  164367  Hyderabad

# %%
df.tail()  #Using show 5 data row in document last
# Out:
#       Name  Age  Working Years  Salary   Location
# 15   Nitin   41             25   28469      Delhi
# 16   Priya   58             19   43709  Bangalore
# 17  Ramesh   36              4  191159    Kolkata
# 18  Sunita   38             24  192753    Kolkata
# 19   Anand   34              2   53395  Bangalore

# %%
df.describe()  #Describe data document
# Out:
#              Age  Working Years         Salary
# count  20.000000       20.00000      20.000000
# mean   43.350000       17.65000  115699.750000
# std    11.735125       10.53453   59591.585252
# min    22.000000        1.00000   28469.000000
# 25%    35.500000       11.25000   70153.000000
# 50%    44.000000       18.50000  123977.000000
# 75%    55.250000       25.50000  161466.000000
# max    58.000000       35.00000  194793.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           20 non-null     object
#  1   Age            20 non-null     int64
#  2   Working Years  20 non-null     int64
#  3   Salary         20 non-null     int64
#  4   Location       20 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 932.0+ bytes

# %% [markdown]
# Data Selection

# %%
df["Name"]
# Out:
# 0       Amit
# 1      Rohit
# 2     Suresh
# 3     Mahesh
# 4      Pooja
# 5       Neha
# 6     Vikram
# 7      Kiran
# 8     Rajesh
# 9     Anjali
# 10     Sneha
# 11     Arjun
# 12    Deepak
# 13    Kavita
# 14     Suman
# 15     Nitin
# 16     Priya
# 17    Ramesh
# 18    Sunita
# 19     Anand
# Name: Name, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
df[["Name", "Location"]]
# Out:
#       Name   Location
# 0     Amit     Mumbai
# 1    Rohit     Mumbai
# 2   Suresh     Jaipur
# 3   Mahesh  Bangalore
# 4    Pooja  Hyderabad
# 5     Neha    Kolkata
# 6   Vikram  Bangalore
# 7    Kiran  Ahmedabad
# 8   Rajesh  Ahmedabad
# 9   Anjali    Lucknow
# 10   Sneha    Kolkata
# 11   Arjun     Mumbai
# 12  Deepak  Hyderabad
# 13  Kavita       Pune
# 14   Suman      Delhi
# 15   Nitin      Delhi
# 16   Priya  Bangalore
# 17  Ramesh    Kolkata
# 18  Sunita    Kolkata
# 19   Anand  Bangalore

# %%
df.iloc[0]  #first row data show
# Out:
# Name               Amit
# Age                  56
# Working Years         9
# Salary           145902
# Location         Mumbai
# Name: 0, dtype: object

# %%
df2= pd.read_csv("data_copy.csv",  encoding="ISO-8859-1")

# %%
df2.head()
# Out:
#      Name   Age  Working Years  Salary   Location
# 0    Amit  56.0            9.0  145902     Mumbai
# 1   Rohit  49.0            NaN  194793     Mumbai
# 2  Suresh  37.0            3.0  160499     Jaipur
# 3  Mahesh  37.0            NaN  148495  Bangalore
# 4   Pooja  56.0           12.0  164367  Hyderabad

# %%
df2.dropna()
# Out:
#       Name   Age  Working Years  Salary   Location
# 0     Amit  56.0            9.0  145902     Mumbai
# 2   Suresh  37.0            3.0  160499     Jaipur
# 4    Pooja  56.0           12.0  164367  Hyderabad
# 6   Vikram  52.0           19.0   41908  Bangalore
# 7    Kiran  49.0           18.0   77144  Ahmedabad
# 8   Rajesh  22.0           31.0   82206  Ahmedabad
# 9   Anjali  27.0           28.0  194642    Lucknow
# 10   Sneha  55.0           14.0   85237    Kolkata
# 11   Arjun  30.0            1.0   31116     Mumbai
# 12  Deepak  28.0           22.0   75739  Hyderabad
# 13  Kavita  57.0           33.0  147395       Pune
# 14   Suman  47.0           35.0  153015      Delhi
# 15   Nitin  41.0           25.0   28469      Delhi
# 16   Priya  58.0           19.0   43709  Bangalore
# 17  Ramesh  36.0            4.0  191159    Kolkata
# 18  Sunita  38.0           24.0  192753    Kolkata
# 19   Anand  34.0            2.0   53395  Bangalore

# %%
df2.fillna(0)
# Out:
#       Name   Age  Working Years  Salary   Location
# 0     Amit  56.0            9.0  145902     Mumbai
# 1    Rohit  49.0            0.0  194793     Mumbai
# 2   Suresh  37.0            3.0  160499     Jaipur
# 3   Mahesh  37.0            0.0  148495  Bangalore
# 4    Pooja  56.0           12.0  164367  Hyderabad
# 5     Neha   0.0           27.0  102052    Kolkata
# 6   Vikram  52.0           19.0   41908  Bangalore
# 7    Kiran  49.0           18.0   77144  Ahmedabad
# 8   Rajesh  22.0           31.0   82206  Ahmedabad
# 9   Anjali  27.0           28.0  194642    Lucknow
# 10   Sneha  55.0           14.0   85237    Kolkata
# 11   Arjun  30.0            1.0   31116     Mumbai
# 12  Deepak  28.0           22.0   75739  Hyderabad
# 13  Kavita  57.0           33.0  147395       Pune
# 14   Suman  47.0           35.0  153015      Delhi
# 15   Nitin  41.0           25.0   28469      Delhi
# 16   Priya  58.0           19.0   43709  Bangalore
# ...

# %%
df.rename(columns={"Location": "Locate"})
# Out:
#       Name  Age  Working Years  Salary     Locate
# 0     Amit   56              9  145902     Mumbai
# 1    Rohit   49             12  194793     Mumbai
# 2   Suresh   37              3  160499     Jaipur
# 3   Mahesh   37             15  148495  Bangalore
# 4    Pooja   56             12  164367  Hyderabad
# 5     Neha   58             27  102052    Kolkata
# 6   Vikram   52             19   41908  Bangalore
# 7    Kiran   49             18   77144  Ahmedabad
# 8   Rajesh   22             31   82206  Ahmedabad
# 9   Anjali   27             28  194642    Lucknow
# 10   Sneha   55             14   85237    Kolkata
# 11   Arjun   30              1   31116     Mumbai
# 12  Deepak   28             22   75739  Hyderabad
# 13  Kavita   57             33  147395       Pune
# 14   Suman   47             35  153015      Delhi
# 15   Nitin   41             25   28469      Delhi
# 16   Priya   58             19   43709  Bangalore
# 17  Ramesh   36              4  191159    Kolkata
# ...

# %%
df
# Out:
#       Name  Age  Working Years  Salary   Location
# 0     Amit   56              9  145902     Mumbai
# 1    Rohit   49             12  194793     Mumbai
# 2   Suresh   37              3  160499     Jaipur
# 3   Mahesh   37             15  148495  Bangalore
# 4    Pooja   56             12  164367  Hyderabad
# 5     Neha   58             27  102052    Kolkata
# 6   Vikram   52             19   41908  Bangalore
# 7    Kiran   49             18   77144  Ahmedabad
# 8   Rajesh   22             31   82206  Ahmedabad
# 9   Anjali   27             28  194642    Lucknow
# 10   Sneha   55             14   85237    Kolkata
# 11   Arjun   30              1   31116     Mumbai
# 12  Deepak   28             22   75739  Hyderabad
# 13  Kavita   57             33  147395       Pune
# 14   Suman   47             35  153015      Delhi
# 15   Nitin   41             25   28469      Delhi
# 16   Priya   58             19   43709  Bangalore
# 17  Ramesh   36              4  191159    Kolkata
# ...

# %%
df.rename(columns={"Location": "Locate"}, inplace=True)

# %%
df
# Out:
#       Name  Age  Working Years  Salary     Locate
# 0     Amit   56              9  145902     Mumbai
# 1    Rohit   49             12  194793     Mumbai
# 2   Suresh   37              3  160499     Jaipur
# 3   Mahesh   37             15  148495  Bangalore
# 4    Pooja   56             12  164367  Hyderabad
# 5     Neha   58             27  102052    Kolkata
# 6   Vikram   52             19   41908  Bangalore
# 7    Kiran   49             18   77144  Ahmedabad
# 8   Rajesh   22             31   82206  Ahmedabad
# 9   Anjali   27             28  194642    Lucknow
# 10   Sneha   55             14   85237    Kolkata
# 11   Arjun   30              1   31116     Mumbai
# 12  Deepak   28             22   75739  Hyderabad
# 13  Kavita   57             33  147395       Pune
# 14   Suman   47             35  153015      Delhi
# 15   Nitin   41             25   28469      Delhi
# 16   Priya   58             19   43709  Bangalore
# 17  Ramesh   36              4  191159    Kolkata
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           20 non-null     object
#  1   Age            20 non-null     int64
#  2   Working Years  20 non-null     int64
#  3   Salary         20 non-null     int64
#  4   Locate         20 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 932.0+ bytes

# %%
df["Age"] = df["Age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           20 non-null     object
#  1   Age            20 non-null     int64
#  2   Working Years  20 non-null     int64
#  3   Salary         20 non-null     int64
#  4   Locate         20 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 932.0+ bytes

# %%
len(df)
# Out:
# 20

# %%
df["Zero"] = [0 for i in range(len(df))]

# %%
df
# Out:
#       Name  Age  Working Years  Salary     Locate  Zero
# 0     Amit   56              9  145902     Mumbai     0
# 1    Rohit   49             12  194793     Mumbai     0
# 2   Suresh   37              3  160499     Jaipur     0
# 3   Mahesh   37             15  148495  Bangalore     0
# 4    Pooja   56             12  164367  Hyderabad     0
# 5     Neha   58             27  102052    Kolkata     0
# 6   Vikram   52             19   41908  Bangalore     0
# 7    Kiran   49             18   77144  Ahmedabad     0
# 8   Rajesh   22             31   82206  Ahmedabad     0
# 9   Anjali   27             28  194642    Lucknow     0
# 10   Sneha   55             14   85237    Kolkata     0
# 11   Arjun   30              1   31116     Mumbai     0
# 12  Deepak   28             22   75739  Hyderabad     0
# 13  Kavita   57             33  147395       Pune     0
# 14   Suman   47             35  153015      Delhi     0
# 15   Nitin   41             25   28469      Delhi     0
# ...

# %%
def fx(a):
    return a*a
df["Increament"] = df["Age"].apply(fx)

# %%
df
# Out:
#       Name  Age  Working Years  Salary     Locate  Zero  zeros+1  Increament
# 0     Amit   56              9  145902     Mumbai     0     3136        3136
# 1    Rohit   49             12  194793     Mumbai     0     2401        2401
# 2   Suresh   37              3  160499     Jaipur     0     1369        1369
# 3   Mahesh   37             15  148495  Bangalore     0     1369        1369
# 4    Pooja   56             12  164367  Hyderabad     0     3136        3136
# 5     Neha   58             27  102052    Kolkata     0     3364        3364
# 6   Vikram   52             19   41908  Bangalore     0     2704        2704
# 7    Kiran   49             18   77144  Ahmedabad     0     2401        2401
# 8   Rajesh   22             31   82206  Ahmedabad     0      484         484
# 9   Anjali   27             28  194642    Lucknow     0      729         729
# 10   Sneha   55             14   85237    Kolkata     0     3025        3025
# ...

# %%
df.to_csv("bonus.csv", index=False)

# %%
df1= pd.DataFrame({
    "name":["Rohit", "Riya", "Muskan", "Manish", "Divya"],
    "marks":[100, 23, 45, 56, 67]
})

# %%
df1
# Out:
#      name  marks
# 0   Rohit    100
# 1    Riya     23
# 2  Muskan     45
# 3  Manish     56
# 4   Divya     67

# %%
df2= pd.DataFrame({
    "name":["Radha", "shyam", "Ram", "KLrishna"],
    "marks":[17, 77, 88, 99]
})

# %%
df2
# Out:
#        name  marks
# 0     Radha     17
# 1     shyam     77
# 2       Ram     88
# 3  KLrishna     99

# %%
pd.concat([df1, df2])
# Out:
#        name  marks
# 0     Rohit    100
# 1      Riya     23
# 2    Muskan     45
# 3    Manish     56
# 4     Divya     67
# 0     Radha     17
# 1     shyam     77
# 2       Ram     88
# 3  KLrishna     99

# %%
df1 =  pd.DataFrame({
    "name":["Rohit", "Muskan"],
    "marks":[100, 98]
})

# %%
df1
# Out:
#      name  marks
# 0   Rohit    100
# 1  Muskan     98

# %%
df2 =  pd.DataFrame({
    "name":["Rohit", "Muskan"],
    "Roll nu.":[1089, 1098]
})

# %%
df2
# Out:
#             name  Roll nu.
# 0  Rohit foujdar      1089
# 1         Muskan      1098

# %%
pd.merge(df1, df2, on="name") #skipped the value to other data
# Out:
#      name  marks  Roll nu.
# 0   Rohit    100      1089
# 1  Muskan     98      1098
